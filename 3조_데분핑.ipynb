# %% [markdown]
# <a href="https://colab.research.google.com/github/yeojeong735/Data-analysis-ping/blob/main/3%E1%84%8C%E1%85%A9_%E1%84%83%E1%85%A6%E1%84%87%E1%85%AE%E1%86%AB%E1%84%91%E1%85%B5%E1%86%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3조_데분핑

# %% [markdown]
# 환경 설정

# %%
# %config InlineBackend.figure_format = 'retina' # matplotlib 선명하게

# %%
import matplotlib.pyplot as plt # 한글처리

plt.rc('font', family='Malgun Gothic')
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rc('axes', unicode_minus=False)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 1. 국내 해수면 온도 편차 그래프

# %% [markdown]
# ### 2. 전지구 해수면 온도 편차 그래프

# %%
import pandas as pd
pop = pd.read_csv("전지구 해수면온도.csv", encoding = 'utf-8', index_col = 0, thousands = ',')
pop
# Out:
#       전지구 연평균 해수면온도 편차
# 연도
# 1891              -0.5
# 1892              -0.6
# 1893              -0.6
# 1894              -0.6
# 1895              -0.5
# ...                ...
# 2019               0.2
# 2020               0.2
# 2021               0.1
# 2022               0.2
# 2023               0.4
#
# [133 rows x 1 columns]

# %%
from matplotlib import pyplot as plt
pop['전지구 연평균 해수면온도 편차'].plot(kind='line', figsize=(8, 4), color='HotPink', title='전지구 연평균 해수면온도 편차')
# Out:
# <Axes: title={'center': '전지구 연평균 해수면온도 편차'}, xlabel='연도'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# ...

# %% [markdown]
# ### 3. 국내 해수면 높이 그래프

# %% [markdown]
# ### 4. 전지구 해수면 높이 그래프

# %%
# 그래프 그리기
plt.figure(figsize=(12, 6))
plt.plot(data['연도'], data['전지구 평균 해수면 높이'], color='magenta', label='해수면 높이 변화')

# 그래프 설정
plt.title('전지구 해수면 높이 변화', fontweight='bold')
plt.xlabel('연도')
plt.ylabel('해수면 높이 (mm)')
plt.axhline(0, color='black', linestyle='--', linewidth=0.8)  # 기준선
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### 5. 전지구 해수면 온도편차와 높이 그래프
